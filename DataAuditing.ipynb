# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.cElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "san-francisco_california.osm"  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

k = 30 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
# work with sample file. Let's audit and look at the street names. 
import pprint

def count_tags(filename):
        tags={}
        for event, elem in ET.iterparse(filename):
            if(elem.tag == 'None'):
                pass
            elif(elem.tag not in tags.keys()):
                tags[elem.tag] = 1
            else:
                tags[elem.tag]+=1
        return tags
count_tags('san-francisco_california.osm')
# Out:
# {'bounds': 1,
#  'member': 53772,
#  'nd': 7448039,
#  'node': 6278429,
#  'osm': 1,
#  'relation': 6012,
#  'tag': 1994316,
#  'way': 770438}

# %%
import pprint
import re
"""
Your task is to explore the data a bit more.
Before you process the data and add it into your database, you should check the
"k" value for each "<tag>" and see if there are any potential problems.

We have provided you with 3 regular expressions to check for certain patterns
in the tags. As we saw in the quiz earlier, we would like to change the data
model and expand the "addr:street" type of keys to a dictionary like this:
{"address": {"street": "Some value"}}
So, we have to see if we have such tags, and if we have any tags with
problematic characters.

Please complete the function 'key_type', such that we have a count of each of
four tag categories in a dictionary:
  "lower", for tags that contain only lowercase letters and are valid,
  "lower_colon", for otherwise valid tags with a colon in their names,
  "problemchars", for tags with problematic characters, and
  "other", for other tags that do not fall into the other three categories.
See the 'process_map' and 'test' functions for examples of the expected format.
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag=="tag":
        if lower.search(element.attrib['k']):
            keys["lower"] +=1
        elif lower_colon.search(element.attrib['k']):
            keys["lower_colon"]+=1
        elif problemchars.search(element.attrib['k']):
            keys["problemchars"]+=1
        else:
            keys["other"]+=1
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
    return keys
process_map('san-francisco_california.osm')
# how to deal with problemchars
# Out:
# {'lower': 128299, 'lower_colon': 69108, 'other': 2547, 'problemchars': 13}

# %%
# return street names
import re
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types;
#audit('san-francisco_california.osm')

# %%
street_mapping = {"151": "",
           "15th": "15th Street",
           "2": "",
           "Avenie":"Avenue",
           "203": "",
           "302": "",
           "3500": "",
           "3658": "",
           "4": "",
           "404": "",
           "502": "",
           "AVE": "Avenue",
           "Airport": "San Francisco International Airport",
           "Alameda": "Alameda Street",
           "Alto": "Alto Route",
           "Ave": "Avenue",
           "Ave. ": "Avenue",
           "Blvd": "Boulevard",
           "Blvd, ": "Boulevard",
           "Blvd.": "Boulevard",
           "California": "California Street",
           "Cres": "Crescent",
           "Ctr": "Center",
               "Dr": "Drive",
           "Hwy": "Highway",
           "Ln.": "Lane",
           "North": "",
           "Rd": "Road",
           "Rd.": "Road",
           "St": "Street",
           "St.": "Street",
           "broadway": "Broadway",
           "square": "Square",
           "st": "Street",
           "street":"Street",
           "way":"Way",
            }

def update_name(name, mapping):
    m = street_type_re.search(name)
    other_street_types = []
    if m:
        street_type= m.group( )
        print m
        if street_type in mapping.keys( ):
            name = re.sub(street_type,mapping[street_type],name)
        else:
            other_street_types.append(street_type)
    return name


def clean_streets(osmfile):
    st_types = audit(osmfile)
    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, street_mapping)
            print name, "=>", better_name
#street_cleaning()

# %%
# audit city names
import re
from collections import defaultdict

def audit_city(invalid_city_names, city_name):
    invalid_city_names.add(city_name)
    return invalid_city_names
            
def is_city_name(elem):
    return (elem.attrib['k'] == "addr:city")

def auditCITY(osmfile): # executes city listings
    osm_file = open(osmfile, "r")
    city_types = set([])
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_city_name(tag):
                    audit_city(city_types, tag.attrib['v'])
    osm_file.close()
    return city_types
auditCITY('san-francisco_california.osm')                
# Alameda incorrections to Alameda
# Berkeley, CA --> truncate Berkeley, CA to Berkeley
# Emeyville --> Emeryville
# All weird oaklands --> Oakland
# Pleasant Hill, CA to Pleasant Hill
# SAN CARLOS to San Carlos
# alameda to Alameda, berkeley, castro valley,
# Out:
# {'11720',
#  '155',
#  '157',
#  '952',
#  'Alamda',
#  'Alameda',
#  'Alamo',
#  'Albany',
#  'Artherton',
#  'Atherton',
#  'Belmont',
#  'Belvedere Tiburon',
#  'Berkeley',
#  'Berkeley, CA',
#  'Brisbane',
#  'Burlingame',
#  'Canyon',
#  'Castro Valley',
#  'Colma',
#  'Concord',
#  'Daly City',
#  'Danville',
#  'East Palo Alto',
#  'El Cerrito',
#  'Emerald Hills',
#  'Emeryville',
#  'Emeyville',
#  'Foster City',
#  'Fremont',
#  'Fremont ',
#  'Greenbrae',
#  'Half Moon Bay',
#  'Hayward',
#  'Hillsborough',
#  'Kensington',
#  'Kentfield',
#  'Lafayette',
#  'Larkspur',
#  'Marin City',
#  'Menlo Park',
#  'Milbrae',
#  'Mill Valley',
#  'Millbrae',
#  'Montara',
#  'Moraga',
#  'Moss Beach',
#  'Muir Beach',
#  'Newark',
#  'OAKLAND',
#  'Oakland',
#  'Oakland ',
#  'Oakland CA',
#  'Oakland, CA',
#  'Oakland, Ca',
#  'Okaland',
#  'Orinda',
#  'PT RICHMOND',
#  'Pacifica',
#  'Palo Alto',
#  'Piedmont',
#  'Pleasant Hill',
#  'Pleasant Hill, CA',
#  'Point Richmond',
#  'Redwood City',
#  'Richmond',
#  'SAN CARLOS',
#  'San Bruno',
#  'San Carlos',
#  'San Francisco',
#  'San Leandro',
#  'San Lorenzo',
#  'San Mateo',
#  'San Pablo',
#  'San Quentin',
#  'San Rafael',
#  'Sausalito',
#  'Sausalito ',
#  'South San Francisco',
#  'Stinson Beach',
#  'Strawberry',
#  'Tiburon',
#  'Union City',
#  'Walnut Creek',
#  'Woodside',
#  'alameda',
#  'berkeley',
#  'castro valley',
#  'daly City',
#  'hayward',
#  'menlo park',
#  'oakland',
#  'richmond',
#  'san Carlos',
#  'san Mateo',
#  'south San Francisco',
#  'walnut Creek'}

# %%
# Update city names based on audit & note 11720','155','157','952',
def update_name_city(name, citymapping):
    if name in citymapping: 
        name = citymapping[name]       
        return name
    else:
        return name
citymapping = {
    "Alamda": "Alameda",
    "Alamo": "Alameda",
    "Artherton": "Atherton",
    "Berkeley, CA": "Berkeley",
    "berkeley": "Berkeley",
    "Emeyville": "Emeryville",
    "Fremont ": "Fremont",
    'OAKLAND': "Oakland",
    'Oakland ': "Oakland",
    'Oakland CA': "Oakland",
    'Oakland, CA': "Oakland",
    'Oakland, Ca': "Oakland",
    "Okaland": "Oakland",
    "Pleasant Hill, CA": "Pleasant Hill",
    "PT RICHMOND": "Point Richmond",
    "SAN CARLOS": "San Carlos",
    "Sausalito ": "Sausalito",
    "alameda": "Alameda",
    "castro valley": "Castro Valley",
    "daly city":"Daly City",
    "hayward": "Hayward",
    "menlo park": "Menlo Park",
    "oakland": "Oakland",
    "richmond": "Richmond",
    "san Carlos": "San Carlos",
    "san Mateo": "San Mateo",
    "south San Francisco": "South San Francisco",
    "walnut Creek": "Walnut Creek"
    
}
def clean_cities(osmfile):
    for event, element in ET.iterparse(osmfile, events=("start","end")):
        if element.tag == "node" or element.tag == "way":
            for tag in element.iter("tag"):

                if tag.attrib['k'] == "addr:city":
                    tag.attrib['v'] = update_name_city(tag.attrib['v'], citymapping);
                    #print tag.attrib['v']

# %%
import re
from collections import defaultdict
amenitylist = []

def audit_amenity(amenity_names, amenity):
    amenity_names.add(amenity)
    return amenity_names;
            
def is_amenity(elem):
    return (elem.attrib['k'] == "amenity");

def auditAMMENITY(osmfile): # executes city listings
    osm_file = open(osmfile, "r")
    amenity_names = set([])
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_amenity(tag):
                    audit_amenity(amenity_names, tag.attrib['v'])
    osm_file.close()
    return amenity_names;
#auditAMMENITY('san-francisco_california.osm');
# takeaway: all amenities are good

# %%
def audit_post(postal_codes, code):
    postal_codes.add(code)
    return postal_codes
            
def is_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

def auditCode(osmfile): # executes city listings
    osm_file = open(osmfile, "r")
    postal_codes = set([])
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_code(tag):
                    audit_post(postal_codes, tag.attrib['v'])
    osm_file.close()
    return postal_codes;

# takeaway: fix remove "CA" 
# truncate after five digits
# map CA ZIPCODE to just Zip Code

# %%
def clean_postal_code(post_code):   
    if(post_code[0] != '9' and post_code[0] != 'C'):
        post_code = 'Invalid Zip Code'
    elif(post_code == 'CA'):
        post_code = 'Invalid Zip Code'
    elif(len(post_code) > 5): #truncate zip codes that have secondary codes with a (-)
        if(post_code[:3] == 'CA ' or post_code[:3] == 'CA:'): # 'CA 94080' case
            post_code = post_code[3:]
        elif(post_code[:3] == 'CA9'):
            post_code = post_code[2:]
    return post_code

# execution code: clean the postal codes
def clean_postal(osmfile):
    for event, element in ET.iterparse(osmfile, events=("start","end")):
        if element.tag == "node" or element.tag == "way":
            for tag in element.iter("tag"):        
                if tag.attrib['k'] == "addr:postcode":
                    tag.attrib['v'] = clean_postal_code(tag.attrib['v'])
                    #print tag.attrib['v']

# %%
def clean_everything(osmfile):
    clean_streets(osmfile);
    clean_cities(osmfile);
    clean_postal(osmfile);
clean_everything("san-francisco_california.osm")
# Out:
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# New Montgomery => New Montgomery
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# St Marys Rd => St Marys Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Buena Vista Rd => Buena Vista Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mecartney Rd => Mecartney Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Willow Rd => Willow Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Se Quad I-680 / Rudgear Rd => Se Quad I-680 / Rudgear Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# St Jude Rd => St Jude Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ascot Rd => Ascot Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ygnacio Valley Rd => Ygnacio Valley Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Mateo Rd => San Mateo Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Marshlands Rd => Marshlands Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Rollins Rd => Rollins Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Market Street Suite 3658 => Market Street Suite
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# broadway => Broadway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alameda => Alameda Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# The Alameda => The Alameda Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bay and Powell => Bay and Powell
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Vallejo Street Stairway => Vallejo Street Stairway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alcatraz Landing => Alcatraz Landing
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Corte Yolanda => Corte Yolanda
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 16th St #404 => 16th St #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Menlo Ave  # 4 => Menlo Ave  #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pacific Marina => Pacific Marina
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Leandro Marina => San Leandro Marina
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Indian Rock Path => Indian Rock Path
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Oak Street Path => Oak Street Path
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mendocino Path => Mendocino Path
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Arden Path => Arden Path
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Parnassus Path => Parnassus Path
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Multi Use Building => Multi Use Building
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ferry Building => Ferry Building
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# E Of Center St @ I-580 => E Of Center St @ I-580
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Clemente => San Clemente
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# El Camino Real #D => El Camino Real #D
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue D => Avenue D
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Marina Boulevard Building D => Marina Boulevard Building D
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue H => Avenue H
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bay => Bay
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bancroft Steps => Bancroft Steps
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Fishermans Wharf => Fishermans Wharf
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Muir Beach Overlook => Muir Beach Overlook
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ross Alley => Ross Alley
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lilac Alley => Lilac Alley
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# August Alley => August Alley
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Redfield Alley => Redfield Alley
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hodges Alley => Hodges Alley
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bradshaw => Bradshaw
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Broadway => Broadway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# North Broadway => North Broadway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 33 union square => 33 union Square
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Embarcadero West => Embarcadero West
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Buena Vista Avenue West => Buena Vista Avenue West
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Industrial Parkway West => Industrial Parkway West
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wellesley Cres => Wellesley Crescent
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mason => Mason
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Fort Mason => Fort Mason
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# townsend street => townsend Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Vallejo street => Vallejo Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# ALA 84 PM 3.2 => ALA 84 PM 3.2
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Inner Circle => Inner Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lafayette Circle => Lafayette Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Croydon Circle => Croydon Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Juan Bautista Circle => Juan Bautista Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Positano Circle => Positano Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Harding Circle => Harding Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Camino Verde Circle => Camino Verde Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Gloria Circle => Gloria Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bridgepointe Circle => Bridgepointe Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# The Circle => The Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Holly Park Circle => Holly Park Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Outer Circle => Outer Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tyson Circle => Tyson Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wilson Circle => Wilson Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Saint James Circle => Saint James Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Murray Circle => Murray Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Blossom Circle => Blossom Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Citrus Circle => Citrus Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Columbia Circle => Columbia Circle
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Francisco Boulevard East => Francisco Boulevard East
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Buena Vista Avenue East => Buena Vista Avenue East
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sir Francis Drake Boulevard East => Sir Francis Drake Boulevard East
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Francisco/Oakland Bridge Toll Pl => San Francisco/Oakland Bridge Toll Pl
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue of the Palms => Avenue of the Palms
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Santa Cruz avenue => Santa Cruz avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South Park => South Park
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Woodside Plz => Woodside Plz
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# University Dr. Suite 3 => University Dr. Suite 3
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Via la Cumbre => Via la Cumbre
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# N Side Of Foothill Blvd @ John Dr (Near I-580) => N Side Of Foothill Blvd @ John Dr (Near I-580)
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Via Ferlinghetti => Via Ferlinghetti
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pier => Pier
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 15th => 15th Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue Del Ora => Avenue Del Ora
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# King => King
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Menalto Ave. => Menalto Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Jefferson Ave. => Jefferson Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hamilton Ave. => Hamilton Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Willie Stargell Ave. => Willie Stargell Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Edes Ave. => Edes Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Santa Cruz Ave. => Santa Cruz Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Carlos Ave. => San Carlos Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lincoln Ave. => Lincoln Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Dartmouth Ave. => Dartmouth Ave.
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue G => Avenue G
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mission Blvd #302 => Mission Blvd #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bay Bridge Toll Plaza => Bay Bridge Toll Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Toll Plaza => Toll Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alamo Plaza => Alamo Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# United Nations Plaza => United Nations Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mint Plaza => Mint Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Woodside Plaza => Woodside Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# SM-Hayward Br Toll Plaza => SM-Hayward Br Toll Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Camino Plaza => Camino Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Frank H Ogawa Plaza => Frank H Ogawa Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Willie Mays Plaza => Willie Mays Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Frank H. Ogawa Plaza => Frank H. Ogawa Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Civic Center Plaza => Civic Center Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ferry Plaza => Ferry Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Manor Plaza => Manor Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lakeshore Plaza => Lakeshore Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Crescent Plaza => Crescent Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# El Cerrito Plaza => El Cerrito Plaza
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Palos Verdes Mall => Palos Verdes Mall
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pacific Avenue Mall => Pacific Avenue Mall
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mission Rock => Mission Rock
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Woodside Road, Suite 100 => Woodside Road, Suite 100
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Nw Quad I-280 / Sr 35 Ic @ Jct Hayne Rd, Golf Course Dr, Skyline Blvd, => Nw Quad I-280 / Sr 35 Ic @ Jct Hayne Rd, Golf Course Dr, Skyline Blvd,
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hamlin Loop => Hamlin Loop
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# N California Blvd #105 => N California Blvd #105
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Grand Avenue #105 => Grand Avenue #105
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pier 39 => Pier 39
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# La Casa Via => La Casa Via
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sansome St #3500 => Sansome St #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hyde => Hyde
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# MILLSBRAE AVE => MILLSBRAE Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Via Lugano => Via Lugano
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Short Cut => Short Cut
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bridgeway => Bridgeway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# California St. => California Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Halleck St. => Halleck Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Market St. => Market Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Webster St. => Webster Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Stein Am Rhein => Stein Am Rhein
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Gough => Gough
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Macdonald => Macdonald
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alameda de las Pulgas => Alameda de las Pulgas
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alameda de Las Pulgas => Alameda de Las Pulgas
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avlameda de las Pulgas => Avlameda de las Pulgas
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alamed de las Pulgas => Alamed de las Pulgas
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 3605 Telegraph => 3605 Telegraph
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Devonshire Way => Devonshire Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ranleigh Way => Ranleigh Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Devon Way => Devon Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Piedmont Way => Piedmont Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Summit Way => Summit Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Koret Way => Koret Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Brandy Rock Way => Brandy Rock Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Darien Way => Darien Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hansen Way => Hansen Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Black Fox Way => Black Fox Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wistaria Way => Wistaria Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Moraga Way => Moraga Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Harold Way => Harold Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wayne Way => Wayne Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Kandle Way => Kandle Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Beach Head Way => Beach Head Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Chemical Way => Chemical Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Dwight Way => Dwight Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hillcrest Way => Hillcrest Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Whiting Way => Whiting Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Escolta Way => Escolta Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Rocky Way => Rocky Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sterling Way => Sterling Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Altamont Way => Altamont Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Convention Way => Convention Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hacker Way => Hacker Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Brotherhood Way => Brotherhood Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Eastview Way => Eastview Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Abbott Way => Abbott Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Stoddard Way => Stoddard Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Juanita Way => Juanita Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mayhew Way => Mayhew Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tum Suden Way => Tum Suden Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Poplar Way => Poplar Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Industrial Way => Industrial Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sanchez Way => Sanchez Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# West California Way => West California Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lenox Way => Lenox Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Woodland Way => Woodland Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Thomas L. Berkley Way => Thomas L. Berkley Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Prospect Way => Prospect Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bret Harte Way => Bret Harte Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Enterprise Way => Enterprise Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South Oak Park Way => South Oak Park Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Liberty Ship Way => Liberty Ship Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Dunsmuir Way => Dunsmuir Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sussex Way => Sussex Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South Harbor Way => South Harbor Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Windsor Way => Windsor Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cheshire Way => Cheshire Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mcnulty Way => Mcnulty Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lakeview Way => Lakeview Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Camberly Way => Camberly Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lincoln Way => Lincoln Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Park Way => Park Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Boulevard Way => Boulevard Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cedarwood Way => Cedarwood Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# California Way => California Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lancaster Way => Lancaster Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Marina Way => Marina Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Buckingham Way => Buckingham Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Allston Way => Allston Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hanna Way => Hanna Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Berryessa Way => Berryessa Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Harbor Way => Harbor Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Crystal Way => Crystal Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Richardson Way => Richardson Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Highland Way => Highland Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Seminole Way => Seminole Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South Marina Way => South Marina Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# DNA Way => DNA Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Claremont Way => Claremont Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bancroft Way => Bancroft Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mohican Way => Mohican Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Chantel Way => Chantel Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wessex Way => Wessex Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bel Air Way => Bel Air Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Panoramic Way => Panoramic Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Masonic Way => Masonic Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Christopher Way => Christopher Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Berkeley Way => Berkeley Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Arizona Way => Arizona Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Madison Way => Madison Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Recreation Way => Recreation Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Coliseum Way => Coliseum Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Thomas More Way => Thomas More Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Oriole Way => Oriole Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bayridge Way => Bayridge Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Chelsea Way => Chelsea Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Aerial Way => Aerial Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Glenn Way => Glenn Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Toyon Way => Toyon Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Spring Way => Spring Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Muir Way => Muir Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Shepard Way => Shepard Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Parkwood Way => Parkwood Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Gauss Way => Gauss Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Orinda Way => Orinda Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hilton Way => Hilton Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Martin Luther King Jr. Way => Martin Luther King Jr. Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Indian Way => Indian Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bill Drake Way => Bill Drake Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hamilton Way => Hamilton Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Midfield Way => Midfield Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Embarcadero Way => Embarcadero Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Kohoutek Way => Kohoutek Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sylvan Way => Sylvan Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cambridge Way => Cambridge Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lakemead Way => Lakemead Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bristol Way => Bristol Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tacoma Way => Tacoma Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Clearview Way => Clearview Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Buena Vista Way => Buena Vista Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wilmington Way => Wilmington Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Southview Way => Southview Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Leandro Way => San Leandro Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alida Way => Alida Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Granger Way => Granger Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Eastlake Way => Eastlake Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ludina Way => Ludina Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Terrace Way => Terrace Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Martin Luther King Jr Way => Martin Luther King Jr Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alston Way => Alston Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Red Oak Way => Red Oak Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mills Way => Mills Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mitchell Way => Mitchell Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Oakview Way => Oakview Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Laurel Way => Laurel Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Parkdale Way => Parkdale Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Beach Way => Beach Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Roosevelt Way => Roosevelt Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Museum Way => Museum Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Channing Way => Channing Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bissell Way => Bissell Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Omar Way => Omar Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Edgecliff Way => Edgecliff Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cardinal Way => Cardinal Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cargo Way => Cargo Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Fanning Way => Fanning Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Garden Way => Garden Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Facebook Way => Facebook Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Willard North => Willard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cabrillo Highway North => Cabrillo Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mission Bay Boulevard North => Mission Bay Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Van Ness => Van Ness
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# E & W Of  Us 101 @ Monte Mar & Spencer => E & W Of  Us 101 @ Monte Mar & Spencer
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# La Caminita => La Caminita
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sansome Street Ste 730 => Sansome Street Ste 730
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sansome Street Suite 730 => Sansome Street Suite 730
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Francisco Bicycle Route 2 => San Francisco Bicycle Route
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# California => California Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Orinda way => Orinda Way
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wedemeyer => Wedemeyer
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Post => Post
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Grizzly Peak Blvd. => Grizzly Peak Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# East Francisco Blvd. => East Francisco Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Webster Street #502 => Webster Street #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue B => Avenue B
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pier 50 B => Pier 50 B
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# County Center => County Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Fort Mason Center => Fort Mason Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bon Air Center => Bon Air Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Westlake Shopping Center => Westlake Shopping Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Westlake Center => Westlake Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South Shore Center => South Shore Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Serramonte Center => Serramonte Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Embarcadero Center => Embarcadero Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Crystal Springs Shopping Center => Crystal Springs Shopping Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Seramonte Center => Seramonte Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Corte Madera Town Center => Corte Madera Town Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Linda Mar Shopping Center => Linda Mar Shopping Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue F => Avenue F
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Arguello => Arguello
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Green St => Green Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Madison St => Madison Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Jackson St => Jackson Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Castro St => Castro Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 24th St => 24th Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Market St => Market Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Under I-880 @ 7th St & Linden St => Under I-880 @ 7th Street & Linden Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Park St => Park Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mission St => Mission Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# S Delaware St => S Delaware Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Kelloch & Velasco St => Kelloch & Velasco Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hayes St => Hayes Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Connecticut St => Connecticut Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# York St => York Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 2nd St => 2nd Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Laurel St => Laurel Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Adeline St => Adeline Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Delancey St => Delancey Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mendell St => Mendell Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Valencia St => Valencia Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Colin P Kelly Jr St => Colin P Kelly Jr Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# East 18th St => East 18th Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 19th St => 19th Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Peralta St => Peralta Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Missouri St => Missouri Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# New Montgomery St => New Montgomery Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Granada St => Granada Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Leavenworth St => Leavenworth Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Upton St => Upton Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Williams St => Williams Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 14th St => 14th Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Kearny St => Kearny Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Noe St => Noe Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Under I-580 Btwn Fruitvale / Champion St => Under I-580 Btwn Fruitvale / Champion Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 9th St => 9th Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ashfield => Ashfield
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Southgate => Southgate
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Doolittle Dr, Suite 15 => Doolittle Dr, Suite 15
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Se Quad Sr 1 / Crespi Dr Int => Se Quad Sr 1 / Crespi Dr Int
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 012 Mi Ne Of Sr 1 / Linda Mar Blvd Int => 012 Mi Ne Of Sr 1 / Linda Mar Blvd Int
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Rose Walk => Rose Walk
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Fountain Walk => Fountain Walk
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Terrace Walk => Terrace Walk
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cascade Walk => Cascade Walk
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Camino Sobrante => Camino Sobrante
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Greenwood Ave => Greenwood Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Earl Ave => Earl Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bayshore Ave => Bayshore Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Telegraph Ave => Telegraph Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# E 28th Ave => E 28th Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# McBryde Ave => McBryde Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# University Ave => University Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# W 25th Ave => W 25th Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Thorton Ave => Thorton Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Grant Ave => Grant Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cherry Ave => Cherry Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Magnolia Ave => Magnolia Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Eagle Ave => Eagle Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Floribunda Ave => Floribunda Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Loma Vista Ave => Loma Vista Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Phelan Ave => Phelan Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Geneva Ave => Geneva Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Corte Madera Ave => Corte Madera Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Blenheim Ave => Blenheim Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Pablo Ave => San Pablo Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lorton Ave => Lorton Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Visitacion Ave => Visitacion Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Esplanade Ave => Esplanade Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Morena Ave => Morena Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Oak Grove Ave => Oak Grove Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Huntington Ave => Huntington Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pennsylvania Ave => Pennsylvania Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Palmetto Ave => Palmetto Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Shattuck Ave => Shattuck Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Day Ave => Day Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tehama Ave => Tehama Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Van Ness Ave => Van Ness Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Jerrold Ave => Jerrold Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# California Ave => California Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# W & E Of Us 101 N Of Seminary Ave => W & E Of Us 101 N Of Seminary Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bridge parkway => Bridge parkway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Brannan St #151 => Brannan St #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Oakridge => Oakridge
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# University Ave #155 => University Ave #155
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Woodside Road, Suite 155 => Woodside Road, Suite 155
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Vallejo => Vallejo
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 10675 => 10675
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Garvin Avenie => Garvin Avenue
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# foothill blvd => foothill blvd
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Panoramic Highway => Panoramic Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cabrillo Highway => Cabrillo Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Great Highway => Great Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Redwood Highway => Redwood Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Eastshore Highway => Eastshore Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South Cabrillo Highway => South Cabrillo Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bayshore Highway => Bayshore Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Shoreline Highway => Shoreline Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# North Cabrillo Highway => North Cabrillo Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Coast Highway => Coast Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# El Camino Real => El Camino Real
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South el Camino Real => South el Camino Real
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# West El Camino Real => West El Camino Real
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# S El Camino Real => S El Camino Real
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# South El Camino Real => South El Camino Real
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 12180142 => 12180142
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 19th & Linda San Francisco => 19th & Linda San Francisco
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# lake arrowhead => lake arrowhead
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Embarcadero => Embarcadero
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# The Embarcadero => The Embarcadero
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# W Of Us 101 @ Jct Sr 1 => W Of Us 101 @ Jct Sr 1
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Redwood Hwy => Redwood Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 40 Shoreline Hwy => 40 Shoreline Highway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# California Dr => California Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Monte Verde Dr => Monte Verde Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hillside Dr => Hillside Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Corriente Point Dr => Corriente Point Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Courthouse Dr => Courthouse Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Crescent Dr => Crescent Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Chateau Dr => Chateau Drive
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# McCone Hall => McCone Hall
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alameda De Las => Alameda De Las
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Adrian Court, Suite A => Adrian Court, Suite A
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Upton St #A => Upton St #A
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pier 50 A => Pier 50 A
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# SF 80 PM 4.5 => SF 80 PM 4.5
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bartlett Street #203 => Bartlett Street #
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue E => Avenue E
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tanforan Shopping Ctr => Tanforan Shopping Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Linda Mar Shppng Ctr => Linda Mar Shppng Center
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Upton St 41276 => Upton St 41276
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Avenue M => Avenue M
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# MacArthur Freeway => MacArthur Freeway
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pollard => Pollard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# San Francisco Internation Airport => San Francisco Internation San Francisco International Airport
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# El Camino del Mar => El Camino del Mar
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Camino Alto => Camino Alto Route
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bont Ln. => Bont Lane
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wildwood Gardens => Wildwood Gardens
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alpine Rd. => Alpine Road
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Norwood View => Norwood View
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Pier 1  SM- Hayward Bridge => Pier 1  SM- Hayward Bridge
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# North Via Monte => North Via Monte
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mission => Mission
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Crane st => Crane Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 2640 mason st => 2640 mason Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Kearny st => Kearny Street
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 37°42'46.0"N 122°29'07.1"W => 37°42'46.0"N 122°29'07.1"W
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Leslie => Leslie
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Paramount Terrace => Paramount Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Atalaya Terrace => Atalaya Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Annapolis Terrace => Annapolis Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hemway Terrace => Hemway Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Vine Terrace => Vine Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Inverleith Terrace => Inverleith Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Temescal Terrace => Temescal Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Upper Terrace => Upper Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Alpine Terrace => Alpine Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Greenwood Terrace => Greenwood Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hermosa Terrace => Hermosa Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Eagle Hill Terrace => Eagle Hill Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Chabot Terrace => Chabot Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Radio Terrace => Radio Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Vernon Terrace => Vernon Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Peace Terrace => Peace Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Broadway Terrace => Broadway Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Grenard Terrace => Grenard Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Loyola Terrace => Loyola Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Park View Terrace => Park View Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Bradshaw Terrace => Bradshaw Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Uranus Terrace => Uranus Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tamalpais Terrace => Tamalpais Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Terrace => Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Roselyn Terrace => Roselyn Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sheldon Terrace => Sheldon Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Kittredge Terrace => Kittredge Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Hawthorne Terrace => Hawthorne Terrace
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Camino Pablo => Camino Pablo
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Sawyer Camp Trail & Hillcrest Blvd => Sawyer Camp Trail & Hillcrest Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Anza Blvd => Anza Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Veterans Blvd => Veterans Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Mission Blvd => Mission Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Lewelling Blvd => Lewelling Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 296 Airport Blvd => 296 Airport Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Airport Blvd => Airport Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Fremont Blvd => Fremont Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Skyline Blvd => Skyline Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ardenwood Blvd => Ardenwood Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Cipriani Blvd => Cipriani Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Newark Blvd => Newark Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 2501 East Bayshore Blvd => 2501 East Bayshore Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Terry A Francois Blvd => Terry A Francois Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Junipero Serra & Westborough Blvd => Junipero Serra & Westborough Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Under Ramp Sw Quad Of Us 101 / Sr 92 Ic Off 19th Ave & Fashion Island Blvd => Under Ramp Sw Quad Of Us 101 / Sr 92 Ic Off 19th Ave & Fashion Island Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Tice Valley Blvd => Tice Valley Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 380 Foster City Blvd => 380 Foster City Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Monument Blvd => Monument Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Marina Blvd => Marina Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# N California Blvd => N California Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Canal Blvd => Canal Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 25555 Hesperian Blvd => 25555 Hesperian Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# 600 Leweling Blvd => 600 Leweling Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# S Airport Blvd => S Airport Boulevard
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Nw Quad Sr 84 / Ardenwood Blvd Ic => Nw Quad Sr 84 / Ardenwood Blvd Ic
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Ne Quad I-280 / Edgewood Rd Ic => Ne Quad I-280 / Edgewood Rd Ic
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Se Quad Sr 92 / Ralston Ic => Se Quad Sr 92 / Ralston Ic
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Wellesley Crescent => Wellesley Crescent
# <_sre.SRE_Match object at 0x00000004EECE2F38>
# Clarendon Crescent => Clarendon Crescent
